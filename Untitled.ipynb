# %%
num=[.1,0.001,1.2,1450.0001]
high=0
for num in num:
    
    if num>high:
        high=num
print(f"highest number in given list is {high}")
# Out:
# highest number in given list is 1450.0001

# %%
num=[.1,0.001,1.2,1450.0001]
low=num[0]
for num in num: 
    
    if num<low:
        low=num
print(f"lowest number in given list is {low}")
# Out:
# lowest number in given list is 0.001

# %%
#write a progran to find duplicate value in given list

nums=[1,2,3,4,5,5,6,7,7,8]
num2=[]
for num in nums:
    if num not in num2:
        num2.append(num)
    else:
        print(num)
# Out:
# 5
# 7

# %%
num2=[]
for num in nums:
    if num not in num2:
        num2.append(num)
    else:
        print(num)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 num2=[]
# ----> 2 for num in nums:
#       3     if num not in num2:
#       4         num2.append(num)
#
# NameError: name 'nums' is not defined

# %%
nums=[1,2,3,4,5,5,6,7,7,8]


dict1={}
for num in nums:
    if num not in dict1:
        dict1[num]=1
    else:
        dict1[num]+=1
for i,j in dict1.items():
    if j>1:
        print(i)
    else:
        continue
# Out:
# 5
# 7

# %%
# write a program to find out secong highest value in given list

nums=[1,2,3,4,5,5,6,7,7,8]

nums=sorted(nums)
print(nums[-2])
# Out:
# 7

# %%
nums=[12,1,12,2,22,11,2,88,98]
first=second=nums[0]

for num in nums:
    if num>first:
        second=first
        first=num
    elif num>second and num!=first:
        second=num
print(second)
# Out:
# 88

# %%
num=[.1,0.001,1.2,10,0.0001]
high=0
for num in num:
    
    if num>high:
        high=num
print(f"highest number in given list is {high}")
# Out:
# highest number in given list is 10

# %%
import random

def number_guessing_game():
    print("Welcome to the Number Guessing Game!")
    print("I'm thinking of a number between 1 and 100.")

    # Computer chooses a random number
    secret_number = random.randint(1, 100)
    attempts = 0
    guess = None

    # Loop until the user guesses correctly
    while guess != secret_number:
        try:
            guess = int(input("Enter your guess: "))
            attempts += 1

            if guess < secret_number:
                print("Too low! Try again.")
            elif guess > secret_number:
                print("Too high! Try again.")
            else:
                print(f"🎉 Congratulations! You guessed the number in {attempts} attempts.")
        except ValueError:
            print("Please enter a valid number.")

# Run the game
number_guessing_game()
# Out:
# Welcome to the Number Guessing Game!
# I'm thinking of a number between 1 and 100.
# Enter your guess:  06
# Too low! Try again.
# Enter your guess:  45
# Too high! Try again.
# Enter your guess:  13
# Too low! Try again.
# Enter your guess:  20
# Too low! Try again.
# Enter your guess:  22
# Too high! Try again.
# Enter your guess:  21
# 🎉 Congratulations! You guessed the number in 6 attempts.
